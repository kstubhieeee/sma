# %% [markdown]
# # Social Media Analytics using Plotly & Faker

# %%
# %pip install pandas plotly faker nbformat
# Out:
# Requirement already satisfied: pandas in /home/kstubhie/Desktop/learning/.venv/lib/python3.12/site-packages (3.0.2)
# Requirement already satisfied: plotly in /home/kstubhie/Desktop/learning/.venv/lib/python3.12/site-packages (6.7.0)
# Requirement already satisfied: faker in /home/kstubhie/Desktop/learning/.venv/lib/python3.12/site-packages (40.15.0)
# Requirement already satisfied: nbformat in /home/kstubhie/Desktop/learning/.venv/lib/python3.12/site-packages (5.10.4)
# Requirement already satisfied: numpy>=1.26.0 in /home/kstubhie/Desktop/learning/.venv/lib/python3.12/site-packages (from pandas) (2.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/kstubhie/Desktop/learning/.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: narwhals>=1.15.1 in /home/kstubhie/Desktop/learning/.venv/lib/python3.12/site-packages (from plotly) (2.20.0)
# Requirement already satisfied: packaging in /home/kstubhie/Desktop/learning/.venv/lib/python3.12/site-packages (from plotly) (26.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/kstubhie/Desktop/learning/.venv/lib/python3.12/site-packages (from nbformat) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /home/kstubhie/Desktop/learning/.venv/lib/python3.12/site-packages (from nbformat) (4.26.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/kstubhie/Desktop/learning/.venv/lib/python3.12/site-packages (from nbformat) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in /home/kstubhie/Desktop/learning/.venv/lib/python3.12/site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in /home/kstubhie/Desktop/learning/.venv/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/kstubhie/Desktop/learning/.venv/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/kstubhie/Desktop/learning/.venv/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /home/kstubhie/Desktop/learning/.venv/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in /home/kstubhie/Desktop/learning/.venv/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.9.6)
# Requirement already satisfied: six>=1.5 in /home/kstubhie/Desktop/learning/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /home/kstubhie/Desktop/learning/.venv/lib/python3.12/site-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import random
import plotly.express as px
from faker import Faker

fake = Faker()

# %%
# Generate dataset
sentiments = ['Positive','Negative','Neutral']
hashtags = ['#AI','#Tech','#DataScience','#Python','#Startup']

data = []
for i in range(200):
    post = {
        'user': fake.user_name(),
        'post_text': fake.sentence(),
        'sentiment': random.choice(sentiments),
        'likes': random.randint(10,500),
        'comments': random.randint(1,100),
        'shares': random.randint(1,50),
        'hashtag': random.choice(hashtags)
    }
    data.append(post)

df = pd.DataFrame(data)
df.head()
# Out:
#              user                                post_text sentiment  likes  \
# 0  shannoncochran  Debate fight hour give sing move money.  Positive    451
# 1  morganjennifer             Especially unit red this as.   Neutral    207
# 2          ipayne                  Drive news other watch.  Positive     77
# 3      brooksmary                Worker serve threat also.   Neutral    369
# 4           wward                Way section general into.   Neutral    483
#
#    comments  shares       hashtag
# 0        82       6       #Python
# 1        23      22  #DataScience
# 2        30      23           #AI
# 3        61       1         #Tech
# 4        75       4           #AI

# %%
# Engagement
df['engagement'] = df['likes'] + df['comments'] + df['shares']

# %%
# Sentiment distribution
sentiment_count = df['sentiment'].value_counts().reset_index()
sentiment_count.columns = ['Sentiment','Count']

fig = px.pie(sentiment_count, values='Count', names='Sentiment', title='Sentiment Distribution')
fig.show()

# %%
# Trending hashtags
hashtag_count = df['hashtag'].value_counts().reset_index()
hashtag_count.columns = ['Hashtag','Count']

fig = px.bar(hashtag_count, x='Hashtag', y='Count', title='Trending Hashtags')
fig.show()

# %%
# Engagement scatter
fig = px.scatter(df, x='likes', y='shares', color='sentiment', size='engagement', title='Engagement Analysis')
fig.show()

# %%
# Top posts
top_posts = df.sort_values(by='engagement', ascending=False).head(10)
top_posts[['user','post_text','engagement']]
# Out:
#                user                                          post_text  \
# 74          fholmes   Individual in building economy smile decide dog.
# 36     brandonmarks          Land realize under probably see military.
# 134  jenniferjensen    History perhaps realize today until Republican.
# 189     davidmonroe  Feel admit nice debate participant wall cover ...
# 184        ofrancis                              World add social bar.
# 24          jacob71           Order trip grow down check still lawyer.
# 67   gonzaleznathan             Do sit whom usually school world here.
# 181   charlesmiller         Money could instead environment film fill.
# 188  yolandarosales  Sport practice north old dog Republican cultural.
# 112    johnsonjason                       In strategy article exactly.
#
#      engagement
# 74          607
# 36          597
# 134         596
# 189         595
# 184         594
# 24          588
# 67          588
# 181         587
# 188         586
# 112         583

# %%
# Summary report
report = {
    'Total Posts': len(df),
    'Average Likes': df['likes'].mean(),
    'Average Comments': df['comments'].mean(),
    'Average Shares': df['shares'].mean(),
    'Most Trending Hashtag': df['hashtag'].mode()[0]
}

report
# Out:
# {'Total Posts': 200,
#  'Average Likes': np.float64(258.35),
#  'Average Comments': np.float64(52.125),
#  'Average Shares': np.float64(25.185),
#  'Most Trending Hashtag': '#DataScience'}
